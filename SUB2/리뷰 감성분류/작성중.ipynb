# %%
# !pip install mxnet
# !pip install gluonnlp pandas tqdm
# !pip install sentencepiece
# !pip install transformers
# !pip install torch
# Out:
# Collecting mxnet
#   Downloading mxnet-1.8.0.post0-py2.py3-none-manylinux2014_x86_64.whl (46.9 MB)
#      |████████████████████████████████| 46.9 MB 44 kB/s
# Requirement already satisfied: requests<3,>=2.20.0 in /usr/local/lib/python3.7/dist-packages (from mxnet) (2.23.0)
# Collecting graphviz<0.9.0,>=0.8.1
#   Downloading graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /usr/local/lib/python3.7/dist-packages (from mxnet) (1.19.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (1.24.3)
# Installing collected packages: graphviz, mxnet
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.10.1
#     Uninstalling graphviz-0.10.1:
#       Successfully uninstalled graphviz-0.10.1
# Successfully installed graphviz-0.8.4 mxnet-1.8.0.post0
# Collecting gluonnlp
#   Downloading gluonnlp-0.10.0.tar.gz (344 kB)
#      |████████████████████████████████| 344 kB 12.1 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.1.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.62.0)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from gluonnlp) (1.19.5)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from gluonnlp) (0.29.24)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from gluonnlp) (21.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->gluonnlp) (2.4.7)
# Building wheels for collected packages: gluonnlp
#   Building wheel for gluonnlp (setup.py) ... done
#   Created wheel for gluonnlp: filename=gluonnlp-0.10.0-cp37-cp37m-linux_x86_64.whl size=595732 sha256=6113624421f5c68e31fd0b7919bb4cbaeab108c5b4444ba4f4b47cccd64d8a5d
#   Stored in directory: /root/.cache/pip/wheels/be/b4/06/7f3fdfaf707e6b5e98b79c041e023acffbe395d78a527eae00
# Successfully built gluonnlp
# Installing collected packages: gluonnlp
# Successfully installed gluonnlp-0.10.0
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 11.0 MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.96
# Collecting transformers
#   Downloading transformers-4.10.2-py3-none-any.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 11.9 MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 40.6 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 39.8 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.6.4)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (21.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Collecting huggingface-hub>=0.0.12
#   Downloading huggingface_hub-0.0.17-py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.5 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 25.4 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.12->transformers) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Installing collected packages: tokenizers, sacremoses, pyyaml, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.0.17 pyyaml-5.4.1 sacremoses-0.0.45 tokenizers-0.10.3 transformers-4.10.2
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.9.0+cu102)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (3.7.4.3)

# %%
# !pip install git+https://git@github.com/SKTBrain/KoBERT.git@master
# Out:
# Collecting git+https://****@github.com/SKTBrain/KoBERT.git@master
#   Cloning https://****@github.com/SKTBrain/KoBERT.git (to revision master) to /tmp/pip-req-build-ds1c2nb3
#   Running command git clone -q 'https://****@github.com/SKTBrain/KoBERT.git' /tmp/pip-req-build-ds1c2nb3
# Building wheels for collected packages: kobert
#   Building wheel for kobert (setup.py) ... done
#   Created wheel for kobert: filename=kobert-0.1.2-py3-none-any.whl size=12771 sha256=5b339cc476a6b2961d436fcbd1eaeff07c8d02e161fad53fae1b932c1a0195cd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-bj5or_u0/wheels/d3/68/ca/334747dfb038313b49cf71f84832a33372f3470d9ddfd051c0
# Successfully built kobert
# Installing collected packages: kobert
# Successfully installed kobert-0.1.2

# %%
import torch
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import gluonnlp as nlp
import numpy as np
from tqdm import tqdm, tqdm_notebook

# %%
from kobert.utils import get_tokenizer
from kobert.pytorch_kobert import get_pytorch_kobert_model

# %%
from transformers import AdamW
from transformers.optimization import get_cosine_schedule_with_warmup

# %%
##GPU 사용 시
device = torch.device("cuda:0")

# %%
import pandas as pd

# %%
bertmodel, vocab = get_pytorch_kobert_model()
# Out:
# [██████████████████████████████████████████████████]
# [██████████████████████████████████████████████████]

# %%
# !wget https://drive.google.com/file/d/1tSUWawR4pzyOD3DhQ-hWhLpc0QrdViuV/view?usp=sharing -O mac_train.csv
# Out:
# --2021-09-14 06:26:23--  https://drive.google.com/file/d/1tSUWawR4pzyOD3DhQ-hWhLpc0QrdViuV/view?usp=sharing
# Resolving drive.google.com (drive.google.com)... 142.251.5.101, 142.251.5.102, 142.251.5.139, ...
# Connecting to drive.google.com (drive.google.com)|142.251.5.101|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘mac_train.csv’
#
# mac_train.csv           [ <=>                ]  64.50K  --.-KB/s    in 0.07s
#
# 2021-09-14 06:26:23 (913 KB/s) - ‘mac_train.csv’ saved [66047]

# %%
# !ls -l
# Out:
# total 72
# -rw-r--r-- 1 root root 66047 Sep 14 06:26 mac_train.csv
# drwxr-xr-x 1 root root  4096 Sep  1 19:26 sample_data

# %%
train_data = pd.read_csv('./drive/MyDrive/mac_train.csv')

# %%
train_data.head()
# Out:
#   UserScreenName  ...                                          Tweet URL
# 0           올리즈원  ...  https://twitter.com/olliez_one/status/14330884...
# 1          마늘장아찌  ...  https://twitter.com/drunken9arlic/status/14330...
# 2       not_Joon  ...  https://twitter.com/JoonNot/status/14330419036...
# 3       빡정(동물농장)  ...  https://twitter.com/XWdwcIn5XihkEpX/status/143...
# 4   정치하는엄마들 공식계정  ...  https://twitter.com/MamasPolitical/status/1432...
#
# [5 rows x 11 columns]

# %%
train_dataset = []
for sen, label in zip(train_data['UserName'], train_data['Embedded_text']):
  data_train = []
  data_train.append(sen)
  data_train.append(str(label))

  train_dataset.append(data_train)

# %%
print(train_dataset)
# Out:
# [['@olliez_one', '강혜원 맥도날드 반대운동\n강혜원 절대 죽먹어\n\n계란죽 끓이는법(초간단)\n1.냄비에 밥이랑 물을 넣고 끓인다\n   (물은 밥 양과 같은 높이정도)\n2.보글보글하면 계란을 2개 넣음\n3.휙휙 저어주면서 간장으로 간맞춤\n4.마무리로 파같은거 넣기(개취)\n5.소금후추로 간맞춤 (개취)\n#혜원메일 #혜원버블\n25\n134\n224'], ['@drunken9arlic', '121111(장소 : 맥도날드)\n1\n1'], ['@JoonNot', '자유공원 맥아더씨 동상. \n\n그가 바라보고 있는 시선을 기준으로 180° 방향으로 쭉 가면 놀랍게도 맥도날드가 나옴.\n3\n5'], ['@XWdwcIn5XihkEpX', '요즘 이게 없으면 안된다!하는거는?이란 질문에 다들 농담삼아 햄버거~ㅋㅋ맥도날드~ㅋㅋ이랬는데 됴0이가 팬분들!이라고해서 농담하던 사람들 다 주먹울음중\n4'], ['@MamasPolitical', '[연대/맥도날드에게 사회적 책임을 촉구하는 대책위]\n\n위생불량 맥도날드!\n      나는 불매한다!\n\n#정치하는엄마들 은 온라인과 오프라인으로 1인 시위 함께 하고 있습니다. \n\n#맥도날드 #맥도날드OUT #맥도날드불매운동 #식품안전 #부당징계철회 #모두가엄마다 #정치하는엄마들\n1\n2'], ['@MamasPolitical', '[1인시위] 위생불량 맥도날드, 나는 불매한다!\n\n#맥도날드 #맥도날드OUT #맥도날드불매운동 #식품안전 #부당징계철회 #모두가엄마다 #정치하는엄마들\n\n인증사진을 위 #해쉬태그 달아 SNS에 공유해주시거나 act@politicalmamas.kr 로 보내주시면 웹자보에 추가해드립니다. \n\n함께 해주세요!'], ['@Apex_ikki', '뭔 맥도날드가 가 드라이브 스루점밖에 업냐\n2\n4'], ['@manman_E2', '맥도날드 귀엽게 먹는거 무슨일이냐고\nㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ\nㅠ-ㅠ)~~\nThe following media includes potentially sensitive content. Change settings\nView'], ['@IdentityV_Long_', 'ㅋㅋ\nㅋㅋㅋ\n\nㅋㅋㅋㅋ\nㅋ\nㅋ\nㅋ\nㅋ\nㅋㅋ\nㅋ\nㅋ\n바삭 바삭 바삭 나의 빅터 개쳐웃겨요\n미치겠다 현웃 ㅅㅂㅋ ㅋ  ㅋㅋㅋ  ㅋㅋ\n저 맥도날드 알바생 빅터 연성도 봤었음.. 눈물남\n2'], ['@Ren_Lda011', '맥도날드ㅋㅋㅋㅋㅋㅋㅋㅋ '], ['@bythenan', '걷 다보니\n신촌역맥도날드\n앞이야 ~~~~~~~\n2'], ['@02_EnoEno', '맥도날드 먹을랫는데 김치볶음밥 먹고싶어서 시켯어\n2'], ['@lucijin0313', '영화 끝나면 맥도날드 들려서 포장해가야지\n2'], ['@90ball_', '언니랑 맥도날드 가서\n수줍게\n해피밀 하나 추가하는 상상\n1\n1'], ['@viennawaits4her', '너네 롯데리아가 맥도날드 대척점에 있는거 디게 우습게 생각하는데 니네가 롯데리아 만들어봐 그럼 .\n1\n5'], ['@LeParadice', '아미친 맥도날드 시발ㅋㅋㅋㅋㅋㅋㅋㅋ'], ['@without_grit', 'ㅅㅂ 맥도날드 공계도 그리워하는 케식이'], ['@iMaandoo', '당진 맥도날드에 왜 쿼파치 없오 끄아아아아아악!!!!!!!!'], ['@04_023', '@맥도날드\n맥윙을 돌려내라 ( ･ᴗ･̥̥̥)⸝⸝'], ['@0O_0O_33', '이미 유령 맥도날드 가서 밥 먹고오는 중임\n1'], ['@bythenan', '따지자면은\n서면 쥬디스태화같은\n느낌이잔아 신촌역맥도날드라는 것이\n3'], ['@saint_cutie', '맥도날드 초코콘 먹고시픔'], ['@fhvTjs__', '맥도날드 드라이빙 뜨루 왓서요'], ['@byeastlaw', '카페인 충전^^ @맥도날드 달맞이 https://instagram.com/p/CTTAG4ihtw7/?utm_medium=twitter…'], ['@zbPP88', '내생일 9월7일인대\n별큰거안바라구\n맥도날드어디로든문만잇으면좋겟아\n1'], ['@dnjsgksekdideh1', '맥도날드 해피밀 어디로든문 도라에몽 어디로든 문 양도 받아요 가격 적어서 디엠 주세요'], ['@MER_1PD', '집에 같이먹을 사람도 없고 재료도 없고 사러갈 시간도 없어서 맨날 배달시키는 마럼이 먹는거\n\n닭발\n곱창\n떡볶이\n국밥\n도시락\n초밥\n뿌링클\n육회\n수제버거(or 맥도날드)\n죽\n지코바\n1\n2'], ['@bioomm__', '페이스아이디 무료로 풀려서 보는데 혀누씨 폴더에 맥도날드버거킹kfc스벅\n다있네'], ['@gn2t_', '맥도날드수\n1'], ['@MINARIGIRL', '모여봐요 동물의숲 맥도날드 의상 패스트푸드점 마이디자인 -\n모여봐요 동물의숲 맥도날드 의상 패스트푸드점 마이디자인\n깜찍해서 꼭 다운받아야하는!! 모여봐요 동물의숲 맥도날드 의상 패스트푸드점 마이디자인 넘넘 귀여운 모여봐요 동물의숲 마이디자인 코드가 있어서 공유해보려고 한다:) 꼭 소장하고 싶은 디자인이랄까! 바로바..\nminarigirl.tistory.com'], ['@__carnya__', 'z클로비스 맥도날드\nㅋ\nㅋㅋ\nㅌㅌㅌㅋㅊㅋㅋㅋㅌㅋㅋㅌㅌㅋㅌㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'], ['@tthing_king', '맥도날드 사달라는 윌로우 뒷목 잡고 질질 끌고가는 이든\n너 손에 그거 뭐야\n? 모카커피요\n지건삼\n1\n1\n4'], ['@koreanmineral', '맥도날드 커피쉐이크 내가 먹어본 커피뭐시기 중에서 젤 맛없어 ㅜㅜ.\n1'], ['@suncheonbot', '과거 순천에 KFC와 파파이스, 또 다른 맥도날드가 있었다는 사실은 패스트푸드 매니아를 슬프게 합니다.'], ['@Laophobia', '맥도날드 얘네들 저번엔 불고기버거 빠뜨려서 받으러가는김에 라지세트 하나 시켰더니 이번엔 감튀를 미디움으로 주네. 감튀 하나 복사했다...'], ['@gonzoippai', '집에 가다가 맥도날드 햄버거 사먹어야즤'], ['@hotpack9', '오늘점심은 맥도날드 치즈버거^^\nMcDonald’s\n@McDonalds\n · Aug 31\nReplying to @DestinyTheGame @stonesandsnakes and @Bungie\n2'], ['@giornojosuke', '죠르노 「신이 주는 것은 시련이고, 악마가 주는 것은 쾌락이라고 하네요.」\n죠스케 「그럼 맥도날드 아저씨는.. 악마임까?」'], ['@oo17035333', '맥도날드 해피밀 도라에몽 어디로든 문 개봉 조립 현물 양도합니다 0.4 + gs편택(반택일택)\n1'], ['@833812_', '찬양하는 맥도날드님 \n갈릭버거 재판매 부탁드립니다…\n3\n3\n7'], ['@QuestQ9_CPP', '스탠 : 남자들끼리 모여서 맥도날드에서 "스마일 부탁합니다, 테이크 아웃으로♡" 라고 말하는 벌칙게임을 했습니다. 프란시스가 걸려서 벌칙 수행을 했는데, 카운터 점원이 "앗, 저… 저 30분만 있으면 일 끝나거든요///" 라고 했다. 그날 우리들에게 스마일은 사라졌다.'], ['@know_llll', '닥마라탕이지 맥도날드붐따 우우 \nThe following media includes potentially sensitive content. Change settings\nView'], ['@ACNY_CPP', '~맥도날드~\n테오「그러고보니, 스마일은 왜 0달러죠?」\n루시안「상대방에게 아무런 감정도 없는, 단순한 의무감에 의해 생성된 겉모습뿐인 웃음이라서 1달러의 가치도 없기 때문이겠지.」\n테오「」'], ['@viennawaits4her', '맥도날드는 세계 가장 거대한 감자저장소이다.\n2\n5'], ['@IdentityV_Long_', '감튀 = 우배부\n이거 이정도면 공식 같은데\n맥도날드랑 콜라보 해야하는거 아닌가요\n3'], ['@DreamLoop723', '보프 피코랑 헤어졌을때 비비 찾아가서 울었으려나\n아니면 그냥 둘이 깨끗하게 헤어진건가\n\n보프 슬퍼서 말도 못하고 삡뽑 하고만 울면 비비는 그냥 옆에 앉아서 토닥여주고 ...

# %%
class BERTDataset(Dataset):
    def __init__(self, dataset, sent_idx, label_idx, bert_tokenizer, max_len,
                 pad, pair):
        transform = nlp.data.BERTSentenceTransform(
            bert_tokenizer, max_seq_length=max_len, pad=pad, pair=pair)

        self.sentences = [transform([i[sent_idx]]) for i in dataset]
        self.labels = [np.int32(i[label_idx]) for i in dataset]

    def __getitem__(self, i):
        return (self.sentences[i] + (self.labels[i], ))

    def __len__(self):
        return (len(self.labels))

# %%
## Setting parameters
max_len = 64
batch_size = 64
warmup_ratio = 0.1
num_epochs = 5
max_grad_norm = 1
log_interval = 200
learning_rate =  5e-5

# %%
#BERT 모델, Vocabulary 불러오기
bertmodel, vocab = get_pytorch_kobert_model()
# Out:
# using cached model
# using cached model

# %%
tokenizer = get_tokenizer()
tok = nlp.data.BERTSPTokenizer(tokenizer, vocab, lower=False)
# Out:
# using cached model

# %%
#data_train = BERTDataset(train_dataset, 0, 1, tok, max_len, True, False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-4d4e537ff038> in <module>()
# ----> 1 data_train = BERTDataset(train_dataset, 0, 1, tok, max_len, True, False)
#
# <ipython-input-22-a9b1e492c2b1> in __init__(self, dataset, sent_idx, label_idx, bert_tokenizer, max_len, pad, pair)
#       6
#       7         self.sentences = [transform([i[sent_idx]]) for i in dataset]
# ----> 8         self.labels = [np.int32(i[label_idx]) for i in dataset]
#       9
#      10     def __getitem__(self, i):
#
# <ipython-input-22-a9b1e492c2b1> in <listcomp>(.0)
#       6
#       7         self.sentences = [transform([i[sent_idx]]) for i in dataset]
# ----> 8         self.labels = [np.int32(i[label_idx]) for i in dataset]
#       9
#      10     def __getitem__(self, i):
#
# ValueError: invalid literal for int() with base 10: '강혜원 맥도날드 반대운동\n강혜원 절대 죽먹어\n\n계란죽 끓이는법(초간단)\n1.냄비에 밥이랑 물을 넣고 끓인다\n   (물은 밥 양과 같은 높이정도)\n2.보글보글하면 계란을 2개 넣음\n3.휙휙 저어주면서 간장으로 간맞춤\n4.마무리로 파같은거 넣기(개취)\n5.소금후추로 간맞춤 (개취)\n#혜원메일 #혜원버블\n25\n134\n224'
